# %%
from dota2_api import get_api_json

match_id = 3437521264
match_info = get_api_json('https://api.opendota.com/api/matches/{}'.format(match_id))
match_info['objectives']
# Out:
# [{'key': 6,
#   'player_slot': 1,
#   'slot': 1,
#   'time': 144,
#   'type': 'CHAT_MESSAGE_FIRSTBLOOD'},
#  {'key': 'npc_dota_goodguys_tower1_top',
#   'time': 641,
#   'type': 'building_kill',
#   'unit': 'npc_dota_badguys_siege'},
#  {'key': 'npc_dota_goodguys_tower1_mid',
#   'player_slot': 132,
#   'slot': 9,
#   'time': 794,
#   'type': 'building_kill',
#   'unit': 'npc_dota_hero_sniper'},
#  {'key': 'npc_dota_goodguys_tower2_top',
#   'player_slot': 129,
#   'slot': 6,
#   'time': 923,
#   'type': 'building_kill',
#   'unit': 'npc_dota_hero_faceless_void'},
#  {'key': 'npc_dota_goodguys_tower1_bot',
#   'time': 1028,
#   'type': 'building_kill',
#   'unit': 'npc_dota_badguys_siege'},
#  {'key': 'npc_dota_goodguys_tower2_bot',
#   'player_slot': 132,
#   'slot': 9,
#   'time': 1102,
#   'type': 'building_kill',
#   'unit': 'npc_dota_hero_sniper'},
#  {'key': 'npc_dota_badguys_tower1_mid',
#   'time': 1110,
#   'type': 'building_kill',
#   'unit': 'npc_dota_creep_goodguys_melee'},
#  {'key': 'npc_dota_badguys_tower1_top',
#   'time': 1121,
#   'type': 'building_kill',
#   'unit': 'npc_dota_creep_goodguys_melee'},
#  {'key': 'npc_dota_badguys_tower1_bot',
#   'time': 1216,
#   'type': 'building_kill',
#   'unit': 'npc_dota_creep_goodguys_melee'},
#  {'key': 'npc_dota_badguys_tower2_bot',
#   'player_slot': 3,
#   'slot': 3,
#   'time': 1527,
#   'type': 'building_kill',
#   'unit': 'npc_dota_hero_mirana'},
#  {'key': 'npc_dota_goodguys_tower2_mid',
#   'time': 1535,
#   'type': 'building_kill',
#   'unit': 'npc_dota_creep_badguys_melee'},
#  {'team': 3, 'time': 1577, 'type': 'CHAT_MESSAGE_ROSHAN_KILL'},
#  {'player_slot': 132, 'slot': 9, 'time': 1577, 'type': 'CHAT_MESSAGE_AEGIS'},
#  {'key': 'npc_dota_badguys_tower2_mid',
#   'player_slot': 3,
#   'slot': 3,
#   'time': 1938,
#   'type': 'building_kill',
#   'unit': 'npc_dota_hero_mirana'},
#  {'key': 'npc_dota_goodguys_tower3_top',
#   'player_slot': 132,
#   'slot': 9,
#   'time': 2123,
#   'type': 'building_kill',
#   'unit': 'npc_dota_hero_sniper'},
#  {'key': 'npc_dota_goodguys_healers',
#   'player_slot': 130,
#   'slot': 7,
#   'time': 2193,
#   'type': 'building_kill',
#   'unit': 'npc_dota_hero_necrolyte'},
#  {'team': 2, 'time': 2249, 'type': 'CHAT_MESSAGE_ROSHAN_KILL'},
#  {'player_slot': 0, 'slot': 0, 'time': 2250, 'type': 'CHAT_MESSAGE_AEGIS'},
#  {'key': 'npc_dota_goodguys_healers',
#   'player_slot': 130,
#   'slot': 7,
#   'time': 2336,
#   'type': 'building_kill',
#   'unit': 'npc_dota_hero_necrolyte'},
#  {'key': 'npc_dota_badguys_tower2_top',
#   'player_slot': 3,
#   'slot': 3,
#   'time': 2353,
#   'type': 'building_kill',
#   'unit': 'npc_dota_hero_mirana'},
#  {'team': 2, 'time': 2949, 'type': 'CHAT_MESSAGE_ROSHAN_KILL'},
#  {'player_slot': 3, 'slot': 3, 'time': 2950, 'type': 'CHAT_MESSAGE_AEGIS'},
#  {'key': 'npc_dota_badguys_tower3_mid',
#   'player_slot': 0,
#   'slot': 0,
#   'time': 3231,
#   'type': 'building_kill',
#   'unit': 'npc_dota_hero_puck'},
#  {'key': 'npc_dota_badguys_melee_rax_mid',
#   'player_slot': 0,
#   'slot': 0,
#   'time': 3537,
#   'type': 'building_kill',
#   'unit': 'npc_dota_hero_puck'},
#  {'key': 'npc_dota_badguys_range_rax_mid',
#   'player_slot': 0,
#   'slot': 0,
#   'time': 3543,
#   'type': 'building_kill',
#   'unit': 'npc_dota_hero_puck'},
#  {'key': 'npc_dota_goodguys_tower3_mid',
#   'player_slot': 130,
#   'slot': 7,
#   'time': 3648,
#   'type': 'building_kill',
#   'unit': 'npc_dota_hero_necrolyte'},
#  {'key': 'npc_dota_goodguys_melee_rax_mid',
#   'player_slot': 132,
#   'slot': 9,
#   'time': 3675,
#   'type': 'building_kill',
#   'unit': 'npc_dota_hero_sniper'},
#  {'key': 'npc_dota_goodguys_range_rax_mid',
#   'time': 3720,
#   'type': 'building_kill',
#   'unit': 'npc_dota_badguys_siege'},
#  {'team': 2, 'time': 3800, 'type': 'CHAT_MESSAGE_ROSHAN_KILL'},
#  {'player_slot': 3, 'slot': 3, 'time': 3801, 'type': 'CHAT_MESSAGE_AEGIS'},
#  {'key': 'npc_dota_badguys_healers',
#   'player_slot': 3,
#   'slot': 3,
#   'time': 3895,
#   'type': 'building_kill',
#   'unit': 'npc_dota_hero_mirana'},
#  {'key': 'npc_dota_badguys_tower3_top',
#   'player_slot': 3,
#   'slot': 3,
#   'time': 4515,
#   'type': 'building_kill',
#   'unit': 'npc_dota_hero_mirana'},
#  {'key': 'npc_dota_badguys_healers',
#   'time': 4525,
#   'type': 'building_kill',
#   'unit': 'npc_dota_creep_goodguys_melee_upgraded'},
#  {'team': 2, 'time': 4582, 'type': 'CHAT_MESSAGE_ROSHAN_KILL'},
#  {'player_slot': 3, 'slot': 3, 'time': 4584, 'type': 'CHAT_MESSAGE_AEGIS'},
#  {'key': 'npc_dota_badguys_melee_rax_top',
#   'player_slot': 3,
#   'slot': 3,
#   'time': 4631,
#   'type': 'building_kill',
#   'unit': 'npc_dota_hero_mirana'},
#  {'key': 'npc_dota_badguys_healers',
#   'player_slot': 3,
#   'slot': 3,
#   'time': 4679,
#   'type': 'building_kill',
#   'unit': 'npc_dota_hero_mirana'},
#  {'key': 'npc_dota_badguys_range_rax_top',
#   'time': 4768,
#   'type': 'building_kill',
#   'unit': 'npc_dota_creep_goodguys_ranged'},
#  {'key': 'npc_dota_goodguys_melee_rax_top',
#   'player_slot': 130,
#   'slot': 7,
#   'time': 5014,
#   'type': 'building_kill',
#   'unit': 'npc_dota_hero_necrolyte'},
#  {'key': 'npc_dota_goodguys_range_rax_top',
#   'player_slot': 132,
#   'slot': 9,
#   'time': 5026,
#   'type': 'building_kill',
#   'unit': 'npc_dota_hero_sniper'},
#  {'key': 'npc_dota_goodguys_tower3_bot',
#   'player_slot': 132,
#   'slot': 9,
#   'time': 5072,
#   'type': 'building_kill',
#   'unit': 'npc_dota_hero_sniper'},
#  {'key': 'npc_dota_badguys_healers',
#   'time': 5104,
#   'type': 'building_kill',
#   'unit': 'npc_dota_creep_goodguys_ranged_upgraded'},
#  {'team': 2, 'time': 5191, 'type': 'CHAT_MESSAGE_ROSHAN_KILL'},
#  {'player_slot': 3, 'slot': 3, 'time': 5192, 'type': 'CHAT_MESSAGE_AEGIS'},
#  {'key': 'npc_dota_badguys_tower3_bot',
#   'time': 5520,
#   'type': 'building_kill',
#   'unit': 'npc_dota_creep_goodguys_melee'},
#  {'key': 'npc_dota_badguys_melee_rax_bot',
#   'player_slot': 3,
#   'slot': 3,
#   'time': 5527,
#   'type': 'building_kill',
#   'unit': 'npc_dota_hero_mirana'},
#  {'key': 'npc_dota_badguys_range_rax_bot',
#   'player_slot': 1,
#   'slot': 1,
#   'time': 5528,
#   'type': 'building_kill',
#   'unit': 'npc_dota_hero_lich'},
#  {'key': 'npc_dota_badguys_fort',
#   'time': 5544,
#   'type': 'building_kill',
#   'unit': 'dota_unknown'}]

# %%
def is_destroy_first_tower_induce_win(match_id):
    match_info = get_api_json('https://api.opendota.com/api/matches/{}'.format(match_id))
    win_camp = 'Radiant' if match_info['radiant_win'] is True else 'Dire'
    if match_info['objectives']:
        for objective in sorted(match_info['objectives'], key=lambda x:x['time']):
            if 'key' in objective and 'tower1' in str(objective['key']):
                tower_camp = 'Dire' if 'goodguys' in objective['key'] else 'Radiant'
                if win_camp == tower_camp:
                    return True
                else:
                    return False
    return None
    
is_destroy_first_tower_induce_win(3437521264)
# Out:
# False

# %%
def is_destroy_mid_tower_induce_win(match_id):
    match_info = get_api_json('https://api.opendota.com/api/matches/{}'.format(match_id))
    win_camp = 'Radiant' if match_info['radiant_win'] is True else 'Dire'
    if match_info['objectives']:
        for objective in sorted(match_info['objectives'], key=lambda x:x['time']):
            if 'key' in objective and 'tower1_mid' in str(objective['key']):
                tower_camp = 'Dire' if 'goodguys' in objective['key'] else 'Radiant'
                if win_camp == tower_camp:
                    return True
                else:
                    return False
    return None
    
is_destroy_mid_tower_induce_win(2909956343)

# %%
def is_kill_roshan_induce_win(match_id):
    match_info = get_api_json('https://api.opendota.com/api/matches/{}'.format(match_id))
    win_camp = 'Radiant' if match_info['radiant_win'] is True else 'Dire'
    if match_info['objectives']:
        for objective in sorted(match_info['objectives'], key=lambda x:x['time']):
            if 'type' in objective and 'CHAT_MESSAGE_AEGIS' in str(objective['type']):
                roshan_camp = 'Radiant' if objective['slot'] <= 4 else 'Dire'
                if win_camp == roshan_camp:
                    return True
                else:
                    return False
    return None
    
is_kill_roshan_induce_win(3437521264)
# Out:
# False

# %%
from dota2_api import get_api_json

sql = """SELECT match_id
FROM match_patch where patch >= '7' 
ORDER BY RANDOM()
LIMIT 500"""

# sql = """SELECT
# matches.match_id
# FROM matches
# JOIN match_patch using(match_id)
# JOIN leagues using(leagueid)
# where patch >= '7' 
# ORDER BY RANDOM()
# LIMIT 100
# """

match_ids = get_api_json('https://api.opendota.com/api/explorer?sql={}'.format(sql))['rows']

# %%
true_count = 0
match_count = 0

for mi in match_ids:
#     is_induce_win = is_destroy_mid_tower_induce_win(mi['match_id'])
#     is_induce_win = is_kill_roshan_induce_win(mi['match_id'])
    is_induce_win = is_destroy_first_tower_induce_win(mi['match_id'])
    if is_induce_win is not None:
        match_count += 1
        if is_induce_win is True:
            true_count += 1
            print(mi, 'True')
        else:
            print(mi, 'False')
    else:
        print(mi, 'No Data')

print(match_count, true_count)
# Out:
# {'match_id': 3889358128} True
# {'match_id': 2994582204} No Data
# {'match_id': 3443379452} True
# {'match_id': 3563513021} True
# {'match_id': 3113943898} No Data
# {'match_id': 3525554974} True
# {'match_id': 3395565602} True
# {'match_id': 3240086740} No Data
# {'match_id': 3619034137} True
# {'match_id': 3738028911} True
# {'match_id': 3124136436} No Data
# {'match_id': 2997475614} No Data
# {'match_id': 3888710999} False
# {'match_id': 3572702903} True
# {'match_id': 3456356301} True
# {'match_id': 3673631946} True
# {'match_id': 3210624507} No Data
# {'match_id': 3674954033} True
# {'match_id': 3217001813} No Data
# {'match_id': 3728491951} False
# {'match_id': 2912098111} No Data
# {'match_id': 3613710378} False
# {'match_id': 3877148426} False
# {'match_id': 2929361668} No Data
# {'match_id': 3430152543} True
# {'match_id': 3095399977} No Data
# {'match_id': 3235667380} No Data
# {'match_id': 3453924673} True
# {'match_id': 3780239446} True
# {'match_id': 3255003447} No Data
# {'match_id': 3368668195} True
# {'match_id': 3647458895} True
# {'match_id': 2918594411} No Data
# {'match_id': 3562942078} True
# {'match_id': 3455963463} True
# {'match_id': 3135791879} No Data
# {'match_id': 3521992301} True
# {'match_id': 3189850821} No Data
# {'match_id': 3720933536} False
# {'match_id': 3662803647} True
# {'match_id': 3466063271} No Data
# {'match_id': 3722906978} True
# {'match_id': 3625735522} True
# {'match_id': 3001258873} No Data
# {'match_id': 3737947819} False
# {'match_id': 3296914318} No Data
# {'match_id': 3672410305} True
# {'match_id': 3066526152} No Data
# {'match_id': 3107225318} No Data
# {'match_id': 3275038059} True
# {'match_id': 3250945491} No Data
# {'match_id': 3142994571} No Data
# {'match_id': 2966253607} No Data
# {'match_id': 3249764299} No Data
# {'match_id': 3172518289} No Data
# {'match_id': 3672048053} True
# {'match_id': 3492269033} True
# {'match_id': 3788207664} True
# {'match_id': 3176450334} No Data
# {'match_id': 3723979382} True
# {'match_id': 3176434195} No Data
# {'match_id': 3508713588} No Data
# {'match_id': 3338561811} True

# %%
# sql
# SELECT count(*)
# FROM match_patch where patch >= '7' 

# SELECT match_id
# FROM match_patch where patch >= '7' 
# ORDER BY RANDOM()
# LIMIT 100
